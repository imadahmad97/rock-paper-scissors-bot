# %%
from ultralytics import YOLO
import cv2
import math 

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)  # Set width
cap.set(4, 480)  # Set height

# Load YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")

# Object classes
classNames = ["person", "rock", "paper", "scissors"]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # Process each detection
    for r in results:
        boxes = r.boxes

        # Check if there are boxes detected
        if boxes:
            for box in boxes:
                # Bounding box coordinates
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int

                # Draw bounding box
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

                # Confidence
                confidence = math.ceil((box.conf[0] * 100)) / 100
                print("Confidence --->", confidence)

                # Class name
                cls = int(box.cls[0])
                if cls < len(classNames):
                    print("Class name -->", classNames[cls])

                    # Display class name on the image
                    org = (x1, y1)
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    fontScale = 1
                    color = (255, 0, 0)
                    thickness = 2
                    cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
                else:
                    print("Detected class index out of range:", cls)
        else:
            print("No objects detected")

    # Display the image
    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-01-29 00:06:33.500 python[68593:4358082] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# No objects detected
# 0: 480x640 (no detections), 71.9ms
# Speed: 3.1ms preprocess, 71.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 53.5ms
# Speed: 1.1ms preprocess, 53.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.3
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 51.5ms
# Speed: 1.1ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.3
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.4ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.33
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.75
# Class name --> person
# 0: 480x640 1 person, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.86
# Class name --> person
# 0: 480x640 1 person, 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.79
# Class name --> person
# 0: 480x640 1 person, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# 0: 480x640 2 persons, 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# 0: 480x640 2 persons, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# 0: 480x640 3 persons, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# 0: 480x640 2 persons, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 56
# 0: 480x640 2 persons, 1 chair, 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.87
# Class name --> person
# 0: 480x640 1 person, 48.2ms
# Speed: 1.3ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 48.4ms
# Speed: 1.4ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# 0: 480x640 2 persons, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# 0: 480x640 2 persons, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.87
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.65
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.27
# Class name --> person
# 0: 480x640 1 person, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.4ms
# Speed: 1.2ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 48.0ms
# Speed: 1.1ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# No objects detected
# 0: 480x640 (no detections), 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# 0: 480x640 2 persons, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# 0: 480x640 2 persons, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# 0: 480x640 2 persons, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> person
# 0: 480x640 1 person, 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.0ms
# Speed: 1.4ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 48.4ms
# Speed: 1.3ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# 0: 480x640 2 persons, 50.4ms
# Speed: 1.3ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 52.7ms
# Speed: 1.1ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 51.6ms
# Speed: 1.1ms preprocess, 51.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.4ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.2ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.1ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 51.1ms
# Speed: 1.1ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.38
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.3
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 48.5ms
# Speed: 1.1ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 49.0ms
# Speed: 1.1ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# 0: 480x640 1 person, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.3ms preprocess, 50.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.38
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# 0: 480x640 1 person, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.88
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.43
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.4
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 52.6ms
# Speed: 1.2ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Detected class index out of range: 60
# 0: 480x640 1 person, 1 dining table, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 57.3ms
# Speed: 1.0ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.3
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.1ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.38
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 47.8ms
# Speed: 1.2ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.1ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.3ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.2ms
# Speed: 1.3ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.3ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.3ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.7ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.0ms
# Speed: 1.1ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.4ms preprocess, 49.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.3ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.3ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 57.4ms
# Speed: 1.1ms preprocess, 57.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 56.0ms
# Speed: 1.1ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.3ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.4ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 48.7ms
# Speed: 1.1ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 56.7ms
# Speed: 1.1ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 53.9ms
# Speed: 1.3ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.1ms
# Speed: 1.1ms preprocess, 52.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Detected class index out of range: 27
# 0: 480x640 1 person, 1 tie, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 56.9ms
# Speed: 0.9ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.42
# Detected class index out of range: 27
# 0: 480x640 1 person, 1 tie, 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.2ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 53.6ms
# Speed: 0.9ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 72.0ms
# Speed: 1.0ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 75.1ms
# Speed: 1.2ms preprocess, 75.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 56.0ms
# Speed: 0.9ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 55.8ms
# Speed: 1.1ms preprocess, 55.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Detected class index out of range: 27
# 0: 480x640 1 person, 1 tie, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.27
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Detected class index out of range: 27
# 0: 480x640 1 person, 1 tie, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Detected class index out of range: 27
# 0: 480x640 1 person, 1 tie, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 55.0ms
# Speed: 1.3ms preprocess, 55.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.96
# Class name --> person
# 0: 480x640 1 person, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.96
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.96
# Class name --> person
# 0: 480x640 1 person, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.96
# Class name --> person
# 0: 480x640 1 person, 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.96
# Class name --> person
# ...
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 48.9ms
# Speed: 1.7ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Detected class index out of range: 56
# 0: 480x640 1 person, 1 chair, 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 48.5ms
# Speed: 1.3ms preprocess, 48.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.4ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 0.9ms preprocess, 51.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.9ms
# Speed: 1.3ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.3ms
# Speed: 0.9ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.6ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 58.6ms
# Speed: 1.2ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.9ms
# Speed: 1.1ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.0ms
# Speed: 1.2ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.4ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.6ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 55.3ms
# Speed: 1.1ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 59.2ms
# Speed: 1.1ms preprocess, 59.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.0ms
# Speed: 1.3ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 57.4ms
# Speed: 1.1ms preprocess, 57.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.92
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.9ms
# Speed: 1.1ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 62.1ms
# Speed: 1.1ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.95
# Class name --> person
# 0: 480x640 1 person, 61.1ms
# Speed: 1.7ms preprocess, 61.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 1.4ms preprocess, 51.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.4ms
# Speed: 0.9ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.7ms
# Speed: 1.1ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.1ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.2ms preprocess, 50.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.93
# Class name --> person
# 0: 480x640 1 person, 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.94
# Class name --> person
# 0: 480x640 1 person, 50.9ms
# Speed: 1.7ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
